# %%
# computational imports
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import string

import ast
from ast import literal_eval

import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
sns.set_style("darkgrid")

import wordcloud
from wordcloud import WordCloud
from wordcloud import STOPWORDS

from sklearn import linear_model

# %% [markdown]
# ## Reading data - movies metadata csv

# %%
# Reading the movies metadata csv file into pandas dataframe
movies_metadata = pd.read_csv('original_movies_metadata.csv')
movies_metadata.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  FALSE                                                NaN  65000000
# 2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  FALSE                                                NaN  16000000
# 4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   10/30/1995
# 1  When siblings Judy and Peter discover an encha...  ...   12/15/1995
# 2  A family wedding reignites the ancient feud be...  ...   12/22/1995
# 3  Cheated on, mistreated and stepped on, the wom...  ...   12/22/1995
# 4  Just when George Banks has recovered from his ...  ...    2/10/1995
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# checking the shape of dataframe
movies_metadata.shape
# Out:
# (45466, 24)

# %%
# checking data types of all objects in the dataframe
movies_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %% [markdown]
# # Cleaning Data - movies Dataset

# %%
# Checking NA counts for each object
movies_metadata.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# Creating a new dataset with required fields only
new_movies = movies_metadata[['id', 'title', 'budget', 'genres', 'overview', 'revenue', 'runtime', 'vote_average', 'vote_count', 'tagline', 'popularity', 'release_date', 'spoken_languages']]
new_movies.head()
# Out:
#       id                        title    budget  \
# 0    862                    Toy Story  30000000
# 1   8844                      Jumanji  65000000
# 2  15602             Grumpier Old Men         0
# 3  31357            Waiting to Exhale  16000000
# 4  11862  Father of the Bride Part II         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 2  A family wedding reignites the ancient feud be...          0.0    101.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 4  Just when George Banks has recovered from his ...   76578911.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0
#
#                                              tagline popularity release_date  \
# 0                                                NaN  21.946943   10/30/1995
# 1          Roll the dice and unleash the excitement!  17.015539   12/15/1995
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129   12/22/1995
# 3  Friends are the people who let you be yourself...   3.859495   12/22/1995
# 4  Just When His World Is Back To Normal... He's ...   8.387519    2/10/1995
#
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]
# 3           [{'iso_639_1': 'en', 'name': 'English'}]
# 4           [{'iso_639_1': 'en', 'name': 'English'}]

# %%
# renaming id as movie_id
new_movies = new_movies.rename(columns={'id': 'movie_id'})

# %%
# reviewing the dataset
new_movies.head()
# Out:
#   movie_id                        title    budget  \
# 0      862                    Toy Story  30000000
# 1     8844                      Jumanji  65000000
# 2    15602             Grumpier Old Men         0
# 3    31357            Waiting to Exhale  16000000
# 4    11862  Father of the Bride Part II         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 2  A family wedding reignites the ancient feud be...          0.0    101.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 4  Just when George Banks has recovered from his ...   76578911.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0
#
#                                              tagline popularity release_date  \
# 0                                                NaN  21.946943   10/30/1995
# 1          Roll the dice and unleash the excitement!  17.015539   12/15/1995
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129   12/22/1995
# 3  Friends are the people who let you be yourself...   3.859495   12/22/1995
# 4  Just When His World Is Back To Normal... He's ...   8.387519    2/10/1995
#
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]
# 3           [{'iso_639_1': 'en', 'name': 'English'}]
# 4           [{'iso_639_1': 'en', 'name': 'English'}]

# %%
# getting movies' release year from release date
new_movies['release_date'] = pd.to_datetime(new_movies['release_date'],  errors='coerce')
new_movies['release_date'] = pd.to_datetime(new_movies['release_date'],format='%Y%m%d')

new_movies.release_date = pd.to_datetime(new_movies.release_date)

new_movies['year'] = pd.to_datetime(new_movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] 
                                                                           if x != np.nan else np.nan)

new_movies.drop('release_date', axis=1, inplace=True)

print(new_movies.dtypes)
# Out:
# movie_id             object
# title                object
# budget               object
# genres               object
# overview             object
# revenue             float64
# runtime             float64
# vote_average        float64
# vote_count          float64
# tagline              object
# popularity           object
# spoken_languages     object
# year                 object
# dtype: object

# %%
# getting languages in proper format from spoken languages field
new_movies['languages'] =new_movies['spoken_languages'].apply(lambda x: str(x).split(':')[-1] 
                                                                           if x != np.nan else np.nan).astype(str).replace(r'[^\w\s]|_', '', regex=True)

new_movies.drop('spoken_languages', axis=1, inplace=True)

new_movies.head(3)
# Out:
#   movie_id             title    budget  \
# 0      862         Toy Story  30000000
# 1     8844           Jumanji  65000000
# 2    15602  Grumpier Old Men         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 2  A family wedding reignites the ancient feud be...          0.0    101.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
#
#                                              tagline popularity  year  \
# 0                                                NaN  21.946943  1995
# 1          Roll the dice and unleash the excitement!  17.015539  1995
# 2  Still Yelling. Still Fighting. Still Ready for...    11.7129  1995
#
#    languages
# 0    English
# 1   Français
# 2    English

# %%
# finding any NaN values 
print(new_movies[pd.to_numeric(new_movies.movie_id, errors='coerce').isnull()])
# Out:
#         movie_id title                            budget  \
# 19730  8/20/1997   NaN  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503  9/29/2012   NaN  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587   1/1/2014   NaN  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  overview  revenue  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...  Released      NaN
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...  Released      NaN
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...  Released      NaN
#
#        runtime  vote_average  vote_count tagline             popularity year  \
# 19730      NaN           NaN         NaN     NaN                    NaN  NaT
# 29503      NaN           NaN         NaN     NaN                    NaN  NaT
# 35587      NaN           NaN         NaN     NaN  Beware Of Frost Bites  NaT
#
#       languages
# 19730       nan
# 29503       nan
# 35587       nan

# %%
# Removing NaN values
#new_movies=new_movies.reset_index() 
#new_movies.drop(new_movies[new_movies.movie_id == "8/20/1997"].index, inplace=True)
#new_movies.drop(new_movies[new_movies.movie_id == "9/29/2012"].index, inplace=True)
#new_movies.drop(new_movies[new_movies.movie_id == "1/1/2014"].index, inplace=True)
new_movies.drop(index=[19730, 29503, 35587], inplace=True)

# %%
print(new_movies[pd.to_numeric(new_movies.movie_id, errors='coerce').isnull()])
# Out:
# Empty DataFrame
# Columns: [movie_id, title, budget, genres, overview, revenue, runtime, vote_average, vote_count, tagline, popularity, year, languages]
# Index: []

# %%
# Finding and removing any NaT values
print(new_movies[pd.to_numeric(new_movies.year, errors='coerce').isnull()])
# Out:
#       movie_id                                           title budget  \
# 711     365371            War Stories Our Mother Never Told Us      0
# 734     215107                           Vermont Is for Lovers      0
# 3460     94214                      Jails, Hospitals & Hip-Hop      0
# 3628    207731                                  Boricua's Bond      0
# 5879     99885                             Divine Intervention      0
# ...        ...                                             ...    ...
# 45148   438910                                 Engineering Red      0
# 45203   433711  All Superheroes Must Die 2: The Last Superhero      0
# 45338   335251                  The Land Where the Blues Began      0
# 45410   449131                                           Aprel      0
# 45461   439050                                          Subdue      0
#
#                                                   genres  \
# 711                                                   []
# 734                                                   []
# 3460                       [{'id': 18, 'name': 'Drama'}]
# 3628                                                  []
# 5879   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                  ...
# 45148                                                 []
# 45203  [{'id': 9648, 'name': 'Mystery'}, {'id': 878, ...
# 45338                                                 []
# 45410  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                                 overview  revenue  runtime  \
# 711    Seven New Zealand women speak about their live...      0.0     95.0
# 734    Vermont is for Lovers is an independently prod...      0.0     88.0
# 3460   Jails, Hospitals &amp; Hip-Hop is a cinematic ...     10.0     90.0
# 3628   Tommy, a talented Puerto Rican painter living ...      0.0    105.0
# 5879   Four friends fight an insane man's crusade to ...      0.0     87.0
# ...                                                  ...      ...      ...
# 45148  Engineering Red - 1993  Dir: Andrey I. Y. Petr...      0.0     76.0
# 45203  In a no holds barred documentary, acclaimed jo...      0.0     74.0
# 45338  An exploration of the musical and social origi...      0.0      0.0
# 45410                                                NaN      0.0      NaN
# 45461        Rising and falling between a man and woman.      0.0     90.0
#
#        vote_average  vote_count  \
# 711             0.0         0.0
# 734             0.0         0.0
# 3460            0.0         0.0
# 3628            2.0         1.0
# 5879            0.0         0.0
# ...             ...         ...
# 45148           6.0         2.0
# 45203           4.0         1.0
# 45338           0.0         0.0
# 45410           6.0         1.0
# 45461           4.0         1.0
#
#                                                  tagline popularity year  \
# 711                                                  NaN   0.005625  NaT
# 734                                                  NaN       0.75  NaT
# 3460   three worlds / two million voices / one genera...   0.009057  NaT
# 3628                                                 NaN   0.035352  NaT
# 5879                             His Judgement Cometh...   0.001181  NaT
# ...                                                  ...        ...  ...
# 45148                                                NaN   0.001586  NaT
# 45203                                                NaN    0.00022  NaT
# 45338                                                NaN          0  NaT
# 45410                                                NaN   0.008903  NaT
# 45461         Rising and falling between a man and woman   0.072051  NaT
#
#       languages
# 711
# 734
# 3460
# 3628
# 5879
# ...         ...
# 45148
# 45203   English
# 45338
# 45410
# 45461     فارسی
#
# [87 rows x 13 columns]

# %%
new_movies.isna().sum()
# Out:
# movie_id            0
# title               3
# budget              0
# genres              0
# overview          954
# revenue             3
# runtime           260
# vote_average        3
# vote_count          3
# tagline         25051
# popularity          3
# year                0
# languages           0
# dtype: int64

# %%
new_movies.drop(new_movies[new_movies.year == "NaT"].index, inplace=True)

# %%
print(new_movies[pd.to_numeric(new_movies.year, errors='coerce').isnull()])
# Out:
# Empty DataFrame
# Columns: [movie_id, title, budget, genres, overview, revenue, runtime, vote_average, vote_count, tagline, popularity, year, languages]
# Index: []

# %%
# Changing data types of genres, title, languages, overview, movie_id, budget, tagline, popularity and year fields
new_movies = new_movies.astype({'genres':'string', 'title':'string', 'languages':'string', 'overview':'string', 'movie_id':'int64', 'budget':'int64', 'tagline':'string', 'popularity':'float', 'year':'int64' })
new_movies.dtypes
# Out:
# movie_id          int64
# title            string
# budget            int64
# genres           string
# overview         string
# revenue         float64
# runtime         float64
# vote_average    float64
# vote_count      float64
# tagline          string
# popularity      float64
# year              int64
# languages        string
# dtype: object

# %%
# getting genres in proper format
new_movies['genres'] = new_movies['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] 
                                                                       if isinstance(x, list) else [])

# %%
new_movies.head()
# Out:
#    movie_id                        title    budget  \
# 0       862                    Toy Story  30000000
# 1      8844                      Jumanji  65000000
# 2     15602             Grumpier Old Men         0
# 3     31357            Waiting to Exhale  16000000
# 4     11862  Father of the Bride Part II         0
#
#                          genres  \
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 2  A family wedding reignites the ancient feud be...          0.0    101.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 4  Just when George Banks has recovered from his ...   76578911.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0
#
#                                              tagline  popularity  year  \
# 0                                               <NA>   21.946943  1995
# 1          Roll the dice and unleash the excitement!   17.015539  1995
# 2  Still Yelling. Still Fighting. Still Ready for...   11.712900  1995
# 3  Friends are the people who let you be yourself...    3.859495  1995
# 4  Just When His World Is Back To Normal... He's ...    8.387519  1995
#
#    languages
# 0    English
# 1   Français
# 2    English
# 3    English
# 4    English

# %%
# checking shape of dataframe
new_movies.shape
# Out:
# (45376, 13)

# %%
# Managing missing data
new_movies['title'] = new_movies['title'].fillna(new_movies['title'].mode()[0])
new_movies['genres'].replace(np.nan,'No data',inplace=True)
new_movies['overview'].replace(np.nan,'No data',inplace=True)
new_movies['tagline'].replace(np.nan,'No data',inplace=True)

# %%
new_movies.shape
# Out:
# (45376, 13)

# %%
new_movies.head()
# Out:
#    movie_id                        title    budget  \
# 0       862                    Toy Story  30000000
# 1      8844                      Jumanji  65000000
# 2     15602             Grumpier Old Men         0
# 3     31357            Waiting to Exhale  16000000
# 4     11862  Father of the Bride Part II         0
#
#                          genres  \
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 2  A family wedding reignites the ancient feud be...          0.0    101.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 4  Just when George Banks has recovered from his ...   76578911.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0
#
#                                              tagline  popularity  year  \
# 0                                            No data   21.946943  1995
# 1          Roll the dice and unleash the excitement!   17.015539  1995
# 2  Still Yelling. Still Fighting. Still Ready for...   11.712900  1995
# 3  Friends are the people who let you be yourself...    3.859495  1995
# 4  Just When His World Is Back To Normal... He's ...    8.387519  1995
#
#    languages
# 0    English
# 1   Français
# 2    English
# 3    English
# 4    English

# %%
# removing any movies with budget as 0
new_movies.drop(new_movies[new_movies.budget <= 0].index, inplace=True)
new_movies.drop(new_movies[new_movies.revenue <= 0].index, inplace=True)

# %%
# dropping any NA values if present
new_movies = new_movies.dropna()

# %%
new_movies.shape
# Out:
# (5380, 13)

# %%
# dropping any duplicate values
new_movies = new_movies.drop_duplicates(subset='title', keep="first", inplace=False)
new_movies.head()
# Out:
#    movie_id              title    budget                            genres  \
# 0       862          Toy Story  30000000       [Animation, Comedy, Family]
# 1      8844            Jumanji  65000000      [Adventure, Fantasy, Family]
# 3     31357  Waiting to Exhale  16000000          [Comedy, Drama, Romance]
# 5       949               Heat  60000000  [Action, Crime, Drama, Thriller]
# 8      9091       Sudden Death  35000000     [Action, Adventure, Thriller]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 5  Obsessive master thief, Neil McCauley leads a ...  187436818.0    170.0
# 8  International action superstar Jean Claude Van...   64350171.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 3           6.1        34.0
# 5           7.7      1886.0
# 8           5.5       174.0
#
#                                              tagline  popularity  year  \
# 0                                            No data   21.946943  1995
# 1          Roll the dice and unleash the excitement!   17.015539  1995
# 3  Friends are the people who let you be yourself...    3.859495  1995
# 5                           A Los Angeles Crime Saga   17.924927  1995
# 8                         Terror goes into overtime.    5.231580  1995
#
#    languages
# 0    English
# 1   Français
# 3    English
# 5    Español
# 8    English

# %%
print(f'The shape of the dataframe is {new_movies.shape}')
# Out:
# The shape of the dataframe is (5274, 13)

# %%
# Checking if any NA value exists in the dataset
new_movies.isna().sum()
# Out:
# movie_id        0
# title           0
# budget          0
# genres          0
# overview        0
# revenue         0
# runtime         0
# vote_average    0
# vote_count      0
# tagline         0
# popularity      0
# year            0
# languages       0
# dtype: int64

# %%
new_movies.dropna(how='any', inplace=True)

# %%
mov_df = new_movies.isna().sum()

# %%
movies = new_movies
movies.head(2)
# Out:
#    movie_id      title    budget                        genres  \
# 0       862  Toy Story  30000000   [Animation, Comedy, Family]
# 1      8844    Jumanji  65000000  [Adventure, Fantasy, Family]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
#
#    vote_average  vote_count                                    tagline  \
# 0           7.7      5415.0                                    No data
# 1           6.9      2413.0  Roll the dice and unleash the excitement!
#
#    popularity  year  languages
# 0   21.946943  1995    English
# 1   17.015539  1995   Français

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5274 entries, 0 to 45422
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      5274 non-null   int64
#  1   title         5274 non-null   string
#  2   budget        5274 non-null   int64
#  3   genres        5274 non-null   object
#  4   overview      5274 non-null   string
#  5   revenue       5274 non-null   float64
#  6   runtime       5274 non-null   float64
#  7   vote_average  5274 non-null   float64
#  8   vote_count    5274 non-null   float64
#  9   tagline       5274 non-null   string
#  10  popularity    5274 non-null   float64
#  11  year          5274 non-null   int64
#  12  languages     5274 non-null   string
# dtypes: float64(5), int64(3), object(1), string(4)
# memory usage: 576.8+ KB

# %%
movies.shape
# Out:
# (5274, 13)

# %%
movies.isna().sum()
# Out:
# movie_id        0
# title           0
# budget          0
# genres          0
# overview        0
# revenue         0
# runtime         0
# vote_average    0
# vote_count      0
# tagline         0
# popularity      0
# year            0
# languages       0
# dtype: int64

# %%
# creating a new field Description by merging Overview and Tagline fields
movies['tagline'] = movies['tagline'].fillna('')
movies['description'] = movies['overview'] + movies['tagline']
movies['description'] = movies['description'].fillna('')
movies.head()
# Out:
#    movie_id              title    budget                            genres  \
# 0       862          Toy Story  30000000       [Animation, Comedy, Family]
# 1      8844            Jumanji  65000000      [Adventure, Fantasy, Family]
# 3     31357  Waiting to Exhale  16000000          [Comedy, Drama, Romance]
# 5       949               Heat  60000000  [Action, Crime, Drama, Thriller]
# 8      9091       Sudden Death  35000000     [Action, Adventure, Thriller]
#
#                                             overview      revenue  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0     81.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0    104.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0    127.0
# 5  Obsessive master thief, Neil McCauley leads a ...  187436818.0    170.0
# 8  International action superstar Jean Claude Van...   64350171.0    106.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 3           6.1        34.0
# 5           7.7      1886.0
# 8           5.5       174.0
#
#                                              tagline  popularity  year  \
# 0                                            No data   21.946943  1995
# 1          Roll the dice and unleash the excitement!   17.015539  1995
# 3  Friends are the people who let you be yourself...    3.859495  1995
# 5                           A Los Angeles Crime Saga   17.924927  1995
# 8                         Terror goes into overtime.    5.231580  1995
#
#    languages                                        description
# 0    English  Led by Woody, Andy's toys live happily in his ...
# 1   Français  When siblings Judy and Peter discover an encha...
# 3    English  Cheated on, mistreated and stepped on, the wom...
# 5    Español  Obsessive master thief, Neil McCauley leads a ...
# 8    English  International action superstar Jean Claude Van...

# %% [markdown]
# # Reading data - ratings csv

# %%
# reading Ratings csv file into Pandas dataframe
ratings = pd.read_csv('ratings.csv')
ratings = ratings.drop('timestamp', axis=1)
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
# description of the data in the dataframe
ratings.describe()
# Out:
# count     10.000000
# mean      97.900000
# std       91.808315
# min        9.000000
# 25%       33.250000
# 50%       64.500000
# 75%      128.750000
# max      263.000000
# Name: rating, dtype: float64

# %%
# checking data type of each column
ratings.dtypes
# Out:
# dtype('int64')

# %%
# renaming movieId field 
ratings = ratings.rename(columns={'movieId': 'movie_id'})
ratings.head()
# Out:
#    userId  movie_id  rating
# 0       1         1     4.0
# 1       1         3     4.0
# 2       1         6     4.0
# 3       1        47     5.0
# 4       1        50     5.0

# %%
# Counting no of unique users
len(ratings['userId'].unique())
# Out:
# 610

# %%
# merge `ratings.csv` and `movies.csv` by movieID
df_merged = pd.merge(ratings, movies, on='movie_id')
df_merged.head()
# Out:
#    userId  movie_id  rating                title    budget   genres  \
# 0       1        70     3.0  Million Dollar Baby  30000000  [Drama]
# 1      18        70     3.5  Million Dollar Baby  30000000  [Drama]
# 2      19        70     2.0  Million Dollar Baby  30000000  [Drama]
# 3      34        70     3.5  Million Dollar Baby  30000000  [Drama]
# 4      45        70     4.0  Million Dollar Baby  30000000  [Drama]
#
#                                             overview      revenue  runtime  \
# 0  Despondent over a painful estrangement from hi...  216763646.0    132.0
# 1  Despondent over a painful estrangement from hi...  216763646.0    132.0
# 2  Despondent over a painful estrangement from hi...  216763646.0    132.0
# 3  Despondent over a painful estrangement from hi...  216763646.0    132.0
# 4  Despondent over a painful estrangement from hi...  216763646.0    132.0
#
#    vote_average  vote_count  \
# 0           7.7      2519.0
# 1           7.7      2519.0
# 2           7.7      2519.0
# 3           7.7      2519.0
# 4           7.7      2519.0
#
#                                              tagline  popularity  year  \
# 0  Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 1  Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 2  Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 3  Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 4  Beyond his silence, there is a past. Beyond he...   14.471373  2004
#
#   languages                                        description
# 0   Gaeilge  Despondent over a painful estrangement from hi...
# 1   Gaeilge  Despondent over a painful estrangement from hi...
# 2   Gaeilge  Despondent over a painful estrangement from hi...
# 3   Gaeilge  Despondent over a painful estrangement from hi...
# 4   Gaeilge  Despondent over a painful estrangement from hi...

# %%
# reviewing description of the merged dataset
df_merged.describe()
# Out:
#              userId       movie_id        rating        budget       revenue  \
# count  19251.000000   19251.000000  19251.000000  1.925100e+04  1.925100e+04
# mean     318.714560    2590.680536      3.498156  4.050392e+07  1.545764e+08
# std      184.515892    9014.533579      1.041220  4.632098e+07  2.289803e+08
# min        1.000000       5.000000      0.500000  1.000000e+00  5.000000e+00
# 25%      160.000000     350.000000      3.000000  6.000000e+06  2.222231e+07
# 50%      317.000000     903.000000      3.500000  2.500000e+07  7.794472e+07
# 75%      474.000000    2023.000000      4.000000  5.950000e+07  2.002760e+08
# max      610.000000  123553.000000      5.000000  3.000000e+08  1.845034e+09
#
#             runtime  vote_average    vote_count    popularity          year
# count  19251.000000  19251.000000  19251.000000  19251.000000  19251.000000
# mean     115.985507      6.798244   1295.652434     11.998104   1993.188614
# std       21.881358      0.782507   1500.587901      6.681630     15.809105
# min       66.000000      2.300000      1.000000      0.003013   1915.000000
# 25%      100.000000      6.300000    327.000000      8.191436   1988.000000
# 50%      113.000000      6.900000    688.000000     11.202764   1999.000000
# 75%      126.000000      7.400000   1754.000000     14.003467   2004.000000
# max      216.000000      8.500000  12269.000000    140.950236   2014.000000

# %%
df_merged.dtypes
# Out:
# userId            int64
# movie_id          int64
# rating          float64
# title            string
# budget            int64
# genres           string
# overview         string
# revenue         float64
# runtime         float64
# vote_average    float64
# vote_count      float64
# tagline          string
# popularity      float64
# year              int64
# languages        object
# description      string
# profit          float64
# dtype: object

# %%
# dropping duplicates from merged dataset
df_merged = df_merged.drop_duplicates(subset='title', keep="first", inplace=False)

# %%
# reviewing NA values if any in the dataset
df_merged.isna().sum()
# Out:
# userId          0
# movie_id        0
# rating          0
# title           0
# budget          0
# genres          0
# overview        0
# revenue         0
# runtime         0
# vote_average    0
# vote_count      0
# tagline         0
# popularity      0
# year            0
# languages       0
# description     0
# dtype: int64

# %%
df_merged.head()
# Out:
#      userId  movie_id  rating                                title     budget  \
# 0         1        70     3.0                  Million Dollar Baby   30000000
# 55        1       101     5.0               Leon: The Professional   16000000
# 78        1       157     5.0  Star Trek III: The Search for Spock   18000000
# 89        1       163     5.0                       Ocean's Twelve  110000000
# 155       1       223     3.0                              Rebecca    1288000
#
#                                              genres  \
# 0                                           [Drama]
# 55                         [Thriller, Crime, Drama]
# 78   [Science Fiction, Action, Adventure, Thriller]
# 89                                [Thriller, Crime]
# 155                                [Drama, Mystery]
#
#                                               overview      revenue  runtime  \
# 0    Despondent over a painful estrangement from hi...  216763646.0    132.0
# 55   Leon, the top hit man in New York, has earned ...   45284974.0    110.0
# 78   Admiral Kirk and his bridge crew risk their ca...   87000000.0    105.0
# 89   Danny Ocean reunites with his old flame and th...  362744280.0    125.0
# 155  A self-conscious bride is tormented by the mem...    6000000.0    130.0
#
#      vote_average  vote_count  \
# 0             7.7      2519.0
# 55            8.2      4293.0
# 78            6.4       443.0
# 89            6.4      2169.0
# 155           7.7       346.0
#
#                                                tagline  popularity  year  \
# 0    Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 55   If you want a job done well, hire a professional.   20.477329  1994
# 78                   A dying planet. A fight for life.    6.197298  1984
# 89                           Twelve is the new eleven.   11.869347  2004
# 155      The shadow of this woman darkened their love.    8.590813  1940
#
#      languages                                        description
# 0      Gaeilge  Despondent over a painful estrangement from hi...
# 55     English  Leon, the top hit man in New York, has earned ...
# 78     Pусский  Admiral Kirk and his bridge crew risk their ca...
# 89     English  Danny Ocean reunites with his old flame and th...
# 155   Français  A self-conscious bride is tormented by the mem...

# %% [markdown]
# ## Exploratory Analysis

# %%
# Highest-Grossing movies using "movies" dataset

plt.figure(figsize = (5, 4))

ax = sns.barplot(y = 'title'[:10], x = 'revenue'[:10],  data = movies.nlargest(10, "revenue").head(10), orient='h')

plt.tick_params(labelsize = 9) 

ax.tick_params(axis='x', rotation=90)
plt.title("Highest-Grossing Movies", fontsize = 11)
plt.xlabel("Revenue", fontsize = 11)
plt.ylabel("Movies", fontsize = 11)
plt.grid()
plt.show()

# %%
# Year when most movies were released
df_year = df_merged.groupby('year').count()['movie_id']
df_year.tail()
# Out:
# year
# 2010     7
# 2011    13
# 2012     6
# 2013     5
# 2014     1
# Name: movie_id, dtype: int64

# %%
# Number of movies released by year
movies_per_year = df_merged.year.value_counts()

plt.title('Movies Per Year', size=11)
plt.xlabel('Year')
plt.ylabel('Number of Movies')

sns.lineplot(x=df_merged['year'].unique(), y=movies_per_year, color='darkblue');

# %%
# average of the ratings
df_avg= df_merged['rating'].mean() 

print('The average of all movie ratings is: ', df_avg)
# Out:
# The average of all movie ratings is:  3.297242083758938

# %%
# Reviewing Vote Count distribution
plt.title("Vote Count Distribution", size=11) #setting the title of the plot
plt.xlabel('Vote Count') # setting the x label of the plot
plt.ylabel('Frequency') # setting the y label of the plot
plt.hist(df_merged['vote_count'], color="mediumturquoise", edgecolor='black'); # plotting the points on the histogram

# %%
# formatting the languages field
import string
import re

def strip_character(dataCol):
    r = re.compile(r'[^a-zA-Z !@#$%&*_+-=|\:";<>,./()[\]{}\']')
    return r.sub('', dataCol)


df_merged['languages'] = df_merged['languages'].apply(strip_character)

# %%
# Count of Movies by language 
lang = df_merged.groupby('languages')['languages'].count().nlargest(15)
lang
# Out:
# languages
#  English     629
#               71
#  Espaol       68
#  Franais      51
#  P            36
#  Italiano     32
#  Deutsch      20
#  Latin        12
#  Portugus      8
#  Magyar        7
#                6
#  svenska       5
#  Polski        4
#  Romn          4
#  Trke          4
# Name: languages, dtype: int64

# %%
pd.isna(df_merged['languages'])
# Out:
# 0        False
# 55       False
# 78       False
# 89       False
# 155      False
#          ...
# 19246    False
# 19247    False
# 19248    False
# 19249    False
# 19250    False
# Name: languages, Length: 979, dtype: bool

# %%
df_na = df_merged
df_na.dropna(inplace = True)

df_na['languages'].replace(' ','').fillna('No language', inplace=True)
df_na.shape
# Out:
# (979, 16)

# %%
# overall distribution of data 
df_merged.hist(figsize = (11,11), bins=50);

# %%
# Number of movies released by year
lang_df = df_na.apply(lambda x: x.str.strip() if x.dtype == "string" else x)
mask = (lang_df['languages'].str.len() >= 4)

lang_df = lang_df.loc[mask]
lang_df.head(5)
movies_per_year = lang_df.year.value_counts().sort_values(ascending=True)

plt.title('Movies by Langauges', size=11)
plt.xlabel('Languages')
plt.ylabel('Number of Movies')

plt.hist(lang_df['languages'][:40], color="hotpink", edgecolor='black')
# Out:
# (array([ 1., 28.,  3.,  2.,  0.,  1.,  1.,  2.,  1.,  1.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
# Word cloud based on movie genre
description=" ".join(df_merged.genres.astype(str).to_list())

stopword = set(list(STOPWORDS) + ['br',]) 

wordcloud = WordCloud(width = 1000, height = 800, 
                       background_color ='White', 
                       stopwords = stopword, 
                       min_font_size = 14).generate(description) 

# plotting word cloud
plt.figure(figsize = (8, 5)) 
plt.imshow(wordcloud) 
plt.axis("off")
# Out:
# (-0.5, 999.5, 799.5, -0.5)

# %%
# movies with runtime greater than 40
df_merged = df_merged[df_merged['runtime'] > 40]

plt.hist(df_merged['runtime'],range=(40,200), bins=15, color = 'mediumorchid', edgecolor='black')
plt.title('Runtimes of Movies', fontsize=11)
plt.xlabel('mins', fontsize=11)
plt.ylabel('Movie Counts', fontsize=11)
plt.show()

# %%
# calculating profit
df_merged['profit']=df_merged['revenue'] - df_merged['budget']
df_merged.head(3)
# Out:
#     userId  movie_id  rating                                title    budget  \
# 0        1        70     3.0                  Million Dollar Baby  30000000
# 55       1       101     5.0               Leon: The Professional  16000000
# 78       1       157     5.0  Star Trek III: The Search for Spock  18000000
#
#                                             genres  \
# 0                                          [Drama]
# 55                        [Thriller, Crime, Drama]
# 78  [Science Fiction, Action, Adventure, Thriller]
#
#                                              overview      revenue  runtime  \
# 0   Despondent over a painful estrangement from hi...  216763646.0    132.0
# 55  Leon, the top hit man in New York, has earned ...   45284974.0    110.0
# 78  Admiral Kirk and his bridge crew risk their ca...   87000000.0    105.0
#
#     vote_average  vote_count  \
# 0            7.7      2519.0
# 55           8.2      4293.0
# 78           6.4       443.0
#
#                                               tagline  popularity  year  \
# 0   Beyond his silence, there is a past. Beyond he...   14.471373  2004
# 55  If you want a job done well, hire a professional.   20.477329  1994
# 78                  A dying planet. A fight for life.    6.197298  1984
#
#    languages                                        description       profit
# 0    Gaeilge  Despondent over a painful estrangement from hi...  186763646.0
# 55   English  Leon, the top hit man in New York, has earned ...   29284974.0
# 78         P  Admiral Kirk and his bridge crew risk their ca...   69000000.0

# %%
df_merged[df_merged["profit"]==df_merged["profit"].max()]
# Out:
#       userId  movie_id  rating    title     budget  \
# 7100       5       597     3.0  Titanic  200000000
#
#                           genres  \
# 7100  [Drama, Romance, Thriller]
#
#                                                overview       revenue  \
# 7100  84 years later, a 101-year-old woman named Ros...  1.845034e+09
#
#       runtime  vote_average  vote_count  \
# 7100    194.0           7.5      7770.0
#
#                                         tagline  popularity  year languages  \
# 7100  Nothing on Earth could come between them.    26.88907  1997         P
#
#                                             description        profit
# 7100  84 years later, a 101-year-old woman named Ros...  1.645034e+09

# %%
# profit by year
profit_by_year = df_merged.groupby(["year","title"]).profit.mean().reset_index().sort_values("year", ascending=False)

profit_by_year.head()
# Out:
#      year                                  title       profit
# 978  2014           Sin City: A Dame to Kill For  -25592384.0
# 977  2013                           The Smurfs 2  242434178.0
# 976  2013  The Mortal Instruments: City of Bones   30565421.0
# 975  2013                               R.I.P.D.  -68351500.0
# 974  2013                            Escape Plan   72915111.0

# %%
# Movie Profit by Popularity
df_merged["profit"].corr(df_merged["popularity"])

plt.title("Movie Profit by Popularity",fontsize=11)            
plt.xlabel('popularity',fontsize = 10)
plt.ylabel('profit',fontsize = 10)

plt.scatter(df_merged["popularity"],df_merged["profit"])

plt.xlim([0,170])
plt.show()

# %%
# vote_average by revenue
plt.scatter(x=df_merged.vote_average, y=df_merged.revenue)
plt.title('Vote Average by Revenue',fontsize = 11)
plt.xlabel('Average Voting',fontsize = 10)
plt.ylabel('Revenue',fontsize = 10)

plt.show()

# %%
# Movies with most profit
df_profit = pd.DataFrame(df_merged['profit'].sort_values(ascending = False))
df_profit['title'] = df_merged['title']
data = list(map(str,(df_profit['title'])))
x = list(data[:10])
y = list(df_profit['profit'][:10])

ax = sns.pointplot(x=y,y=x, color='#d62728')

sns.set(rc={'figure.figsize':(6,4)})

ax.set_title("Movies with most Profit",fontsize = 11)
ax.set_xlabel("Profit",fontsize = 11)
# Out:
# Text(0.5, 0, 'Profit')

# %%
# calculate movie profit 
def calc_func(x):
    
    highest = df_merged[x].idxmax()
    highest_details = pd.DataFrame(df_merged.loc[highest])
    
    # calculate minimum value
    lowest = df_merged[x].idxmin()
    lowest_details = pd.DataFrame(df_merged.loc[lowest])  
    
    print('Movie with highest '+x+' : ', df_merged['title'][highest])
    print('Movie with lowest '+x+' : ', df_merged['title'][lowest])

calc_func('profit')
# Out:
# Movie with highest profit :  Titanic
# Movie with lowest profit :  The 13th Warrior

# %%
# movies with least and max profit
def least_most_info (col):

    max_m = df_merged[col].idxmax()
    max_df = pd.DataFrame(df_merged.loc[max_m])
    
    min_m = df_merged[col].idxmin()
    min_df = pd.DataFrame(df_merged.loc[min_m])

    least_most_info = pd.concat([max_df, min_df], axis = 1)
    
    return least_most_info

least_most_info('profit')
# Out:
#                                                           7100   \
# userId                                                        5
# movie_id                                                    597
# rating                                                      3.0
# title                                                   Titanic
# budget                                                200000000
# genres                               [Drama, Romance, Thriller]
# overview      84 years later, a 101-year-old woman named Ros...
# revenue                                            1845034188.0
# runtime                                                   194.0
# vote_average                                                7.5
# vote_count                                               7770.0
# tagline               Nothing on Earth could come between them.
# popularity                                             26.88907
# year                                                       1997
# languages                                                     P
# description   84 years later, a 101-year-old woman named Ros...
# profit                                             1645034188.0
#
#                                                           14737
# userId                                                       19
# movie_id                                                   1911
# rating                                                      2.0
# title                                          The 13th Warrior
# budget                                                160000000
# genres                             [Adventure, Fantasy, Action]
# overview      In AD 922, Arab courtier, Ahmad Ibn Fadlan acc...
# revenue                                              61698899.0
# runtime                                                   102.0
# vote_average                                                6.4
# vote_count                                                524.0
# tagline                                    Prey for the living.
# popularity                                            10.308026
# year                                                       1999
# languages                                                 Norsk
# description   In AD 922, Arab courtier, Ahmad Ibn Fadlan acc...
# profit                                              -98301101.0

# %%
# Movie popularity by runtime
popular_movie = df_merged.groupby('runtime')['popularity'].mean()
popular_movie.plot(figsize = (7,5), color = 'mediumblue')
        
plt.title("Movie popularity by runtime",fontsize=11)            
plt.xlabel('Runtime',fontsize = 11)
plt.ylabel('Popularity',fontsize = 11)

max_run= popular_movie.idxmax()

print('Most popular runtime:', max_run, 'minutes.')
# Out:
# Most popular runtime: 152.0 minutes.

# %%
# getting a list of unique genres 
def unlock_list_from_string(string, delim=','):
    if (type(string)!=str and (string != '')):
        return string

    clean_string = re.sub('\[|\]', '', string)
    print(clean_string)
    unlocked_string = clean_string.split(delim)
    print(unlocked_string)
    unlocked_list = [x.strip() for x in unlocked_string]
    return unlocked_list

unique_genres_nested = df_merged['genres'].apply(unlock_list_from_string)

unique_genres = [x for y in unique_genres_nested for x in y ]
unique_genres = list(set(unique_genres))

unique_genres.sort()
print(unique_genres)
# Out:
# ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Foreign', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction', 'Thriller', 'War', 'Western']

# %%
# Analyzing genres
genre_detail = df_merged.copy()

for genres in unique_genres :
    genre_detail[genres] = genre_detail.apply(lambda _:int(genres in _.genres), axis = 1)

genre_detail.tail(5)
# Out:
#        userId  movie_id  rating                      title     budget  \
# 19246     607       241     4.0       Natural Born Killers   34000000
# 19247     609       137     3.0              Groundhog Day   14600000
# 19248     610      7984     4.0  In the Name of the Father   13000000
# 19249     610      8840     1.0                DragonHeart   57000000
# 19250     610     77931     4.0               The Smurfs 2  105000000
#
#                                      genres  \
# 19246              [Crime, Thriller, Drama]
# 19247     [Romance, Fantasy, Drama, Comedy]
# 19248                               [Drama]
# 19249                             [Fantasy]
# 19250  [Fantasy, Family, Comedy, Animation]
#
#                                                 overview      revenue  \
# 19246  Two victims of traumatized childhoods become l...   50282766.0
# 19247  A narcissistic TV weatherman, along with his a...   70906973.0
# 19248  A small time thief from Belfast, Gerry Conlon,...   65796862.0
# 19249  In an ancient time when majestic fire-breather...  115267375.0
# 19250  The evil wizard Gargamel creates a couple of m...  347434178.0
#
#        runtime  vote_average  ...  Foreign History  Horror  Music Mystery  \
# 19246    119.0           6.9  ...        0       0       0      0       0
# 19247    101.0           7.4  ...        0       0       0      0       0
# 19248    133.0           7.6  ...        0       0       0      0       0
# 19249    103.0           6.4  ...        0       0       0      0       0
# 19250    105.0           5.5  ...        0       0       0      0       0
#
#       Romance  Science Fiction  Thriller  War  Western
# 19246       0                0         1    0        0
# 19247       1                0         0    0        0
# 19248       0                0         0    0        0
# 19249       0                0         0    0        0
# 19250       0                0         0    0        0
#
# [5 rows x 36 columns]

# %%
# Genre percentage and count of occurances
df_merged = df_merged.astype({'genres':'string'})

genres = df_merged['genres'].apply(eval).apply('|'.join)
genres = genres.str.get_dummies(sep='|')

genres_count = genres.sum(axis = 0).to_frame().reset_index()
genres_count.columns =['genres', 'count']
genres_count = genres_count.sort_values(by='count', ascending=False)

print('The total number of genres is:', genres_count.shape[0])
genres_count['percentage(%)'] = round(genres_count['count']/sum(genres_count['count']), 4)*100
genres_count
# Out:
# The total number of genres is: 19
#              genres  count  percentage(%)
# 6             Drama    496          18.49
# 16         Thriller    338          12.60
# 3            Comedy    282          10.51
# 0            Action    271          10.10
# 4             Crime    207           7.72
# 1         Adventure    202           7.53
# 14          Romance    186           6.93
# 15  Science Fiction    146           5.44
# 13          Mystery    114           4.25
# 8           Fantasy    110           4.10
# 11           Horror     81           3.02
# 7            Family     71           2.65
# 10          History     46           1.71
# 17              War     38           1.42
# 2         Animation     36           1.34
# 12            Music     35           1.30
# 18          Western     15           0.56
# 5       Documentary      8           0.30
# 9           Foreign      1           0.04

# %%
# top 10 genres

plt.figure(figsize = (6, 4))

ax = sns.set_palette("Spectral") 
ax = sns.barplot(x = 'genres'[:10],
                 y = 'count'[:10],
                 data = genres_count.head(10))

for q in ax.patches:
    ax.annotate(str(q.get_height()), (q.get_x() * 1.01 , q.get_height() * 1.01))

plt.tick_params(labelsize = 9) 
ax.tick_params(axis='x', rotation=90)
plt.title("Top 10 Popular Genres", fontsize = 11)
plt.xlabel("Genres", fontsize = 11)
plt.ylabel("Count", fontsize = 11)
plt.grid()
plt.show()

# %%
# analyzing ratings in merged dataset
sum_rating = df_merged.groupby(['movie_id', 'title'], as_index=False)['rating'].sum().rename(columns={'rating':'sum'}).sort_values(by='sum', ascending=False)
num_rating = df_merged.groupby(['movie_id'])['title'].count().to_frame().reset_index().rename(columns={'title':'num_rating'})
detail_rating = pd.merge(sum_rating, num_rating, on='movie_id')
detail_rating['average_rating'] = detail_rating['sum']/detail_rating['num_rating']

# Show the top 5 sum of rating
detail_rating_new = detail_rating.drop_duplicates(subset='average_rating')
detail_rating_new.sort_values(by=['average_rating','num_rating'], ascending=False).iloc[:5]
# Out:
#      movie_id                              title  sum  num_rating  \
# 0           5                         Four Rooms  5.0           1
# 130      7459                        Speed Racer  4.5           1
# 164       813                          Airplane!  4.0           1
# 407      1430              Bowling for Columbine  3.5           1
# 480      3563  I Now Pronounce You Chuck & Larry  3.0           1
#
#      average_rating
# 0               5.0
# 130             4.5
# 164             4.0
# 407             3.5
# 480             3.0

# %%
# Counting the number of unique movies in the dataset.
len(ratings['movie_id'].unique())
# Out:
# 9724

# %%
# Distribution of ratings for all movies
ratings = df_merged['rating'].value_counts()
numbers = ratings.index
quantity = ratings.values

colors = sns.color_palette("husl")

plt.figure(figsize = (8,5))
plt.title('Distribution of Ratings')

plt.pie(ratings.index,labels=ratings.values, colors = colors,autopct='%1.1f%%',textprops= {"fontsize": 10},shadow = False)
plt.legend(ratings.index, labels=ratings.values, bbox_to_anchor=(1.5,0), loc="lower right")
plt.show()

# %%
# Correlation Heatmap to check strength of relationships between numerical variables
corr_df = df_merged[['rating','popularity','budget','revenue','runtime','vote_count','vote_average']]
sns.heatmap(corr_df.corr(), linecolor = "White", linewidths =0.75, center = -0.1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot: >

# %%
# Regression Model - correlation between vote counts and popularity to predict popularity against vote counts.

X = df_merged['vote_count'].values.reshape(-1,1)
y = df_merged['popularity'].values

ols = linear_model.LinearRegression()
lm = ols.fit(X, y)
res = lm.predict(X)
r2 = lm.score(X, y)

plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(6, 4))

ax.plot(X, res, color='k')
ax.scatter(X, y, edgecolor='k', facecolor='steelblue', alpha=0.4)
ax.set_ylabel('Vote Count', fontsize=11)
ax.set_xlabel('Popularity', fontsize=11)
ax.legend(facecolor='white', fontsize=11)
ax.set_title(' Regression model $R^2= %.2f$' % r2, fontsize=11)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, ' Regression model $R^2= 0.50$')

# %%
ols.coef_
# Out:
# array([0.0042528])

# %%
ols.intercept_
# Out:
# 6.799784207905876

# %%
ols.predict([[265000000]])
# Out:
# array([1126999.97253045])

# %%
ols.score(X, y)
# Out:
# 0.4976689237855456

# %% [markdown]
# This explains almost 50% of the variations in the popularity considering a single variable.
